# %% [markdown]
# In this notebook, we will have an exercise of text mining: find report categories.
#
# Assume the situation that you have a lot of folder and files (over 10000 files or more),
# only few of them are drilling/completion reports you need.
# And the reports may also be saved in different types as *.pdf, *.doc, *.xlsx
#
# So have a clear workflow to find these files in a clearly organzied folder is very useful.
#
# In this workflow, the judgement is only focus on file names.
#
# ** I use fuzzywuzzy library to calculale string distance.
# Here is the link of how to install and use: https://www.geeksforgeeks.org/fuzzywuzzy-python-library/

# %%
import numpy as np
import pandas as pd 
import os
# import textdistance
from fuzzywuzzy import fuzz
import re
# Out:
# C:\Users\Xiaodan\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ### 1. Scan and get pathes of all files within the given root path

# %%
# function comes from: https://thispointer.com/python-how-to-get-list-of-files-in-directory-and-sub-directories/
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %%
root = r'C:\MXD\courses'
filePath = getListOfFiles(root)

# %%
len(filePath)
# Out:
# 7828

# %%
filePath[1111]
# Out:
# "C:\\MXD\\courses\\PETE 603\\Wattenbarger exam\\ExamB 20'05.pdf"

# %%
# get all file names without path
rows = []
for file in filePath:
    re1 = [i.start() for i in re.finditer(r'[\\]', file)]
    
    FileFullName = file[re1[-1]+1:]
    re2 = [i.start() for i in re.finditer(r'[.]', FileFullName)]
    if re2:
        fileName = FileFullName[:re2[-1]]
        Extension = FileFullName[re2[-1]+1:]
    else:
        fileName = FileFullName 
        Extension = []
    
    dictfile = {'Path': file[:re1[-1]], 'FileFullName': file[re1[-1]+1:], 'FileName': fileName, 'Extension': Extension}
    rows.append(dictfile)
    
df = pd.DataFrame.from_dict(rows, orient='columns')
df.head()
# Out:
#              Path                               FileFullName  \
# 0  C:\MXD\courses  13IPTC_Tian - AYERS COMMENTS - 27 FEB.ppt
# 1  C:\MXD\courses                              1_pvt (1).pdf
# 2  C:\MXD\courses  2011_05_spee_houston_palke_simulation.pdf
# 3  C:\MXD\courses                     648 project-team 4.pdf
# 4  C:\MXD\courses      Anadarko_Lunch_Learn_3_22_2006_v2.pdf
#
#                                 FileName Extension
# 0  13IPTC_Tian - AYERS COMMENTS - 27 FEB       ppt
# 1                              1_pvt (1)       pdf
# 2  2011_05_spee_houston_palke_simulation       pdf
# 3                     648 project-team 4       pdf
# 4      Anadarko_Lunch_Learn_3_22_2006_v2       pdf

# %% [markdown]
# ### 2. find target files by calculate string distance
# since we are looking for some specific files, such as reservoir simulation report, drilling report, ect
#
# we can pre-define a library of each type which contains most frequence words that people may use based on naming habits
#
# ** here I choose to search reservoir files as example

# %%
# reservoir files, could be expended based on naming habits
resKey = {'reserv', 'reservoir', 'reservoirs'}

# %%
def getScore(stra, resKey):
    return max([fuzz.ratio(b.lower(), a) for a in resKey for b in stra.split()])

# %%
def cleanName(stra):
    regex = re.compile('[^a-zA-Z]')
    stra = regex.sub(' ', stra.strip())
    return stra.strip().lower()

# %%
# clean file name, only keep alphabeta
df['CleanName'] = df['FileName'].apply(lambda x: cleanName(x))
df.head()
# Out:
#              Path                               FileFullName  \
# 0  C:\MXD\courses  13IPTC_Tian - AYERS COMMENTS - 27 FEB.ppt
# 1  C:\MXD\courses                              1_pvt (1).pdf
# 2  C:\MXD\courses  2011_05_spee_houston_palke_simulation.pdf
# 3  C:\MXD\courses                     648 project-team 4.pdf
# 4  C:\MXD\courses      Anadarko_Lunch_Learn_3_22_2006_v2.pdf
#
#                                 FileName Extension  \
# 0  13IPTC_Tian - AYERS COMMENTS - 27 FEB       ppt
# 1                              1_pvt (1)       pdf
# 2  2011_05_spee_houston_palke_simulation       pdf
# 3                     648 project-team 4       pdf
# 4      Anadarko_Lunch_Learn_3_22_2006_v2       pdf
#
#                              CleanName
# 0  iptc tian   ayers comments      feb
# 1                                  pvt
# 2        spee houston palke simulation
# 3                         project team
# 4     anadarko lunch learn           v

# %%
# first screen, only keep the pdf files which contains res
mask = (df['CleanName'].str.contains('res'))&(df['Extension']=='pdf')
df = df[mask]
df.head()
# Out:
#                                                   Path  \
# 208  C:\MXD\courses\Coursera\coursera-Applied-Data-...
# 228  C:\MXD\courses\Coursera\coursera-Applied-Data-...
# 239  C:\MXD\courses\Coursera\coursera-Applied-Data-...
# 334                        C:\MXD\courses\Coursera\GIS
# 340                            C:\MXD\courses\GEOL 619
#
#                                           FileFullName  \
# 208                          2.2_Distance-Measures.pdf
# 228                        1.3_Regular-Expressions.pdf
# 239             3.2_Identifying-Features-from-Text.pdf
# 334                  Resources-and-Help_2016_10_09.pdf
# 340  06_07_method_exploration_reservoir_geophysics.pdf
#
#                                           FileName Extension  \
# 208                          2.2_Distance-Measures       pdf
# 228                        1.3_Regular-Expressions       pdf
# 239             3.2_Identifying-Features-from-Text       pdf
# 334                  Resources-and-Help_2016_10_09       pdf
# 340  06_07_method_exploration_reservoir_geophysics       pdf
#
#                                    CleanName
# 208                        distance measures
# 228                      regular expressions
# 239           identifying features from text
# 334                       resources and help
# 340  method exploration reservoir geophysics

# %%
# calculate text distance of filename with keyword dictionary
df['resScore'] = df['CleanName'].apply(lambda x: getScore(x, resKey))
df.head()
# Out:
#                                                   Path  \
# 208  C:\MXD\courses\Coursera\coursera-Applied-Data-...
# 228  C:\MXD\courses\Coursera\coursera-Applied-Data-...
# 239  C:\MXD\courses\Coursera\coursera-Applied-Data-...
# 334                        C:\MXD\courses\Coursera\GIS
# 340                            C:\MXD\courses\GEOL 619
#
#                                           FileFullName  \
# 208                          2.2_Distance-Measures.pdf
# 228                        1.3_Regular-Expressions.pdf
# 239             3.2_Identifying-Features-from-Text.pdf
# 334                  Resources-and-Help_2016_10_09.pdf
# 340  06_07_method_exploration_reservoir_geophysics.pdf
#
#                                           FileName Extension  \
# 208                          2.2_Distance-Measures       pdf
# 228                        1.3_Regular-Expressions       pdf
# 239             3.2_Identifying-Features-from-Text       pdf
# 334                  Resources-and-Help_2016_10_09       pdf
# 340  06_07_method_exploration_reservoir_geophysics       pdf
#
#                                    CleanName  resScore
# 208                        distance measures        43
# 228                      regular expressions        46
# 239           identifying features from text        43
# 334                       resources and help        63
# 340  method exploration reservoir geophysics       100

# %%
# filted out low score files
df[df['resScore']>80]
# Out:
#                                                    Path  \
# 340                             C:\MXD\courses\GEOL 619
# 352                             C:\MXD\courses\GEOL 619
# 353                             C:\MXD\courses\GEOL 619
# 354                             C:\MXD\courses\GEOL 619
# 370                  C:\MXD\courses\GEOL 619\New Folder
# 2552                      C:\MXD\courses\PETE 637\NOTES
# 2577                            C:\MXD\courses\PETE 640
# 2687          C:\MXD\courses\PETE 640\PetE_640_Handouts
# 2708                            C:\MXD\courses\PETE 640
# 2727               C:\MXD\courses\PETE 641\641_Material
# 2753               C:\MXD\courses\PETE 641\641_Material
# 2755               C:\MXD\courses\PETE 641\641_Material
# 5704                            C:\MXD\courses\PETE 663
# 5719                            C:\MXD\courses\PETE 664
# 5721                            C:\MXD\courses\PETE 664
# 5740                    C:\MXD\courses\PETE 664\HW\HW11
# 5765                     C:\MXD\courses\PETE 664\HW\HW4
# 5840                       C:\MXD\courses\PETE 664\note
# 5842                       C:\MXD\courses\PETE 664\note
# 5844                       C:\MXD\courses\PETE 664\note
# 5861                       C:\MXD\courses\PETE 664\note
# 5863                       C:\MXD\courses\PETE 664\note
# 5874                            C:\MXD\courses\PETE 665
# 5875                            C:\MXD\courses\PETE 665
# 5876                            C:\MXD\courses\PETE 665
# 5877                            C:\MXD\courses\PETE 665
# 5878                            C:\MXD\courses\PETE 665
# 5879                            C:\MXD\courses\PETE 665
# 5880                            C:\MXD\courses\PETE 665
# 5881                            C:\MXD\courses\PETE 665
# 5882                            C:\MXD\courses\PETE 665
# 5883                            C:\MXD\courses\PETE 665
# 5884                            C:\MXD\courses\PETE 665
# 5894           C:\MXD\courses\PETE 665\Barrufet\Goodies
# 5912            C:\MXD\courses\PETE 665\Barrufet\Slides
# 5913            C:\MXD\courses\PETE 665\Barrufet\Slides
# 5938          C:\MXD\courses\PETE 665\Nasarabadi\Slides
# 5939          C:\MXD\courses\PETE 665\Nasarabadi\Slides
# 6503      C:\MXD\courses\PETE 689_HPC\HPC Lecture Notes
# 6504      C:\MXD\courses\PETE 689_HPC\HPC Lecture Notes
# 7534                                     C:\MXD\courses
# 7545  C:\MXD\courses\Qualify\Fundamentals of Reservo...
# 7547  C:\MXD\courses\Qualify\Fundamentals of Reservo...
# 7565                                 C:\MXD\courses\RTA
# 7626  C:\MXD\courses\To_XiaoDan_Tingting\GEOL_CARBON...
# 7627  C:\MXD\courses\To_XiaoDan_Tingting\GEOL_CARBON...
# 7633  C:\MXD\courses\To_XiaoDan_Tingting\GEOL_CARBON...
#
#                                            FileFullName  \
# 340   06_07_method_exploration_reservoir_geophysics.pdf
# 352                          15_sandstone_reservoir.pdf
# 353                          16_carbonate_reservoir.pdf
# 354                  17_reservoir_frontier_research.pdf
# 370   Depositional system and reservoir potential of...
# 2552            L09B_Fractured Reservoir Simulation.pdf
# 2577  1555630898_Basic_Applied_Reservoir_Simulation.pdf
# 2687  SOMERTON--High_Temperature_Behavior_of_Rocks_A...
# 2708  SUN,MOHANTY--Simulation_of_Methane_Hydrate_Res...
# 2727  KOCABAS--Thermal_Transiens_During_Nonisotherma...
# 2753  SIDDIQUI--Two-Phase_Relative_Permeability_Mode...
# 2755  SUN,MOHANTY--Simulation_of_Methane_Hydrate_Res...
# 5704  P663_16B_Mod_01c_RESENG_(Reservoir_Fluids)_[v2...
# 5719          ey-us-oil-and-gas-reserves-study-2016.pdf
# 5721                            fmev-chap3-reserves.pdf
# 5740  HW11 - Guidelines for the Evaluation of Petrol...
# 5765  664_HW4 Table 9-1 from Gas reservoir Engineeri...
# 5840  664 Lecture 1-A Classifying and Estimating Res...
# 5842             664 Lecture 10-A MB Oil Reservoirs.pdf
# 5844          664 Lecture 11-A Reservoir Simulators.pdf
# 5861              664 Lecture 8-A MB Gas Reservoirs.pdf
# 5863               664 Lecture 9-A Analogy Reserves.pdf
# 5874             20130408 Reservoir Engineering 665.pdf
# 5875             20130410 Reservoir Engineering 665.pdf
# 5876             20130412 Reservoir Engineering 665.pdf
# 5877             20130415 Reservoir Engineering 665.pdf
# 5878             20130417 Reservoir Engineering 665.pdf
# 5879             20130419 Reservoir Engineering 665.pdf
# 5880             20130421 Reservoir Engineering 665.pdf
# 5881             20130424 Reservoir Engineering 665.pdf
# 5882             20130426 Reservoir Engineering 665.pdf
# 5883             20130429 Reservoir Engineering 665.pdf
# 5884             20130430 Reservoir Engineering 665.pdf
# 5894     Reservoir Fluid Sampling AND Recombination.pdf
# 5912  L2-Fundamentals of Reservoir Fluid Behavior an...
# 5913    L3-Gas Properties for Reservoir Engineering.pdf
# 5938  Supplement Document - Gas_Reservoir_Performanc...
# 5939  Supplement Document - Oil_Reservoir_Performanc...
# 6503  PETE689_HPC_Reservoir_Simulation_Basic_Fall13.pdf
# 6504  PETE689_HPC_Reservoir_Simulation_Basic_II_Fall...
# 7534       petroleum reservoir engineering practice.pdf
# 7545  01_Some Basic Concepts in Reservoir Engineerin...
# 7547  03_Material Balance Applied to Oil Reservoirs.pdf
# 7565             IHS-Reservoir-Engineering-brochure.pdf
# 7626              Diagenetically Defined Reservoirs.pdf
# 7627                           Fractured Reservoirs.pdf
# 7633           Introduction to carbonate reservoirs.pdf
#
#                                                FileName Extension  \
# 340       06_07_method_exploration_reservoir_geophysics       pdf
# 352                              15_sandstone_reservoir       pdf
# 353                              16_carbonate_reservoir       pdf
# 354                      17_reservoir_frontier_research       pdf
# 370   Depositional system and reservoir potential of...       pdf
# 2552                L09B_Fractured Reservoir Simulation       pdf
# 2577      1555630898_Basic_Applied_Reservoir_Simulation       pdf
# 2687  SOMERTON--High_Temperature_Behavior_of_Rocks_A...       pdf
# 2708  SUN,MOHANTY--Simulation_of_Methane_Hydrate_Res...       pdf
# 2727  KOCABAS--Thermal_Transiens_During_Nonisotherma...       pdf
# 2753  SIDDIQUI--Two-Phase_Relative_Permeability_Mode...       pdf
# 2755  SUN,MOHANTY--Simulation_of_Methane_Hydrate_Res...       pdf
# 5704  P663_16B_Mod_01c_RESENG_(Reservoir_Fluids)_[v2...       pdf
# 5719              ey-us-oil-and-gas-reserves-study-2016       pdf
# 5721                                fmev-chap3-reserves       pdf
# 5740  HW11 - Guidelines for the Evaluation of Petrol...       pdf
# 5765   664_HW4 Table 9-1 from Gas reservoir Engineering       pdf
# 5840  664 Lecture 1-A Classifying and Estimating Res...       pdf
# 5842                 664 Lecture 10-A MB Oil Reservoirs       pdf
# 5844              664 Lecture 11-A Reservoir Simulators       pdf
# 5861                  664 Lecture 8-A MB Gas Reservoirs       pdf
# 5863                   664 Lecture 9-A Analogy Reserves       pdf
# 5874                 20130408 Reservoir Engineering 665       pdf
# 5875                 20130410 Reservoir Engineering 665       pdf
# 5876                 20130412 Reservoir Engineering 665       pdf
# 5877                 20130415 Reservoir Engineering 665       pdf
# 5878                 20130417 Reservoir Engineering 665       pdf
# 5879                 20130419 Reservoir Engineering 665       pdf
# 5880                 20130421 Reservoir Engineering 665       pdf
# 5881                 20130424 Reservoir Engineering 665       pdf
# 5882                 20130426 Reservoir Engineering 665       pdf
# 5883                 20130429 Reservoir Engineering 665       pdf
# 5884                 20130430 Reservoir Engineering 665       pdf
# 5894         Reservoir Fluid Sampling AND Recombination       pdf
# 5912  L2-Fundamentals of Reservoir Fluid Behavior an...       pdf
# 5913        L3-Gas Properties for Reservoir Engineering       pdf
# 5938    Supplement Document - Gas_Reservoir_Performance       pdf
# 5939    Supplement Document - Oil_Reservoir_Performance       pdf
# 6503      PETE689_HPC_Reservoir_Simulation_Basic_Fall13       pdf
# 6504   PETE689_HPC_Reservoir_Simulation_Basic_II_Fall13       pdf
# 7534           petroleum reservoir engineering practice       pdf
# 7545    01_Some Basic Concepts in Reservoir Engineering       pdf
# 7547      03_Material Balance Applied to Oil Reservoirs       pdf
# 7565                 IHS-Reservoir-Engineering-brochure       pdf
# 7626                  Diagenetically Defined Reservoirs       pdf
# 7627                               Fractured Reservoirs       pdf
# 7633               Introduction to carbonate reservoirs       pdf
#
#                                               CleanName  resScore
# 340             method exploration reservoir geophysics       100
# 352                                 sandstone reservoir       100
# 353                                 carbonate reservoir       100
# 354                         reservoir frontier research       100
# 370   depositional system and reservoir potential of...       100
# 2552                l  b fractured reservoir simulation       100
# 2577                 basic applied reservoir simulation       100
# 2687  somerton  high temperature behavior of rocks a...       100
# 2708  sun mohanty  simulation of methane hydrate res...       100
# 2727  kocabas  thermal transiens during nonisotherma...       100
# 2753  siddiqui  two phase relative permeability mode...       100
# 2755  sun mohanty  simulation of methane hydrate res...       100
# 5704  p      b mod   c reseng  reservoir fluids   v ...       100
# 5719                   ey us oil and gas reserves study        86
# 5721                                fmev chap  reserves        86
# 5740  hw     guidelines for the evaluation of petrol...        86
# 5765       hw  table     from gas reservoir engineering       100
# 5840    lecture   a classifying and estimating reserves        86
# 5842                     lecture    a mb oil reservoirs       100
# 5844                  lecture    a reservoir simulators       100
# 5861                      lecture   a mb gas reservoirs       100
# 5863                       lecture   a analogy reserves        86
# 5874                              reservoir engineering       100
# 5875                              reservoir engineering       100
# 5876                              reservoir engineering       100
# 5877                              reservoir engineering       100
# 5878                              reservoir engineering       100
# 5879                              reservoir engineering       100
# 5880                              reservoir engineering       100
# 5881                              reservoir engineering       100
# 5882                              reservoir engineering       100
# 5883                              reservoir engineering       100
# 5884                              reservoir engineering       100
# 5894         reservoir fluid sampling and recombination       100
# 5912  l  fundamentals of reservoir fluid behavior an...       100
# 5913        l  gas properties for reservoir engineering       100
# 5938    supplement document   gas reservoir performance       100
# 5939    supplement document   oil reservoir performance       100
# 6503        pete    hpc reservoir simulation basic fall       100
# 6504     pete    hpc reservoir simulation basic ii fall       100
# 7534           petroleum reservoir engineering practice       100
# 7545       some basic concepts in reservoir engineering       100
# 7547         material balance applied to oil reservoirs       100
# 7565                 ihs reservoir engineering brochure       100
# 7626                  diagenetically defined reservoirs       100
# 7627                               fractured reservoirs       100
# 7633               introduction to carbonate reservoirs       100

# %% [markdown]
# ** based on file pathes you can copy them into other target folder
#
# This is very simple example of texting mining.
#
# And there are always lots of ways to do it, like using regular expression, string distance or more.
#
# Regular expression is very useful for the file with well API or some rules on well names.
